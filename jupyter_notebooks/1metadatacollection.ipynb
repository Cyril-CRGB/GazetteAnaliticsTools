# %% [markdown]
# # **METADATA COLLECTION NOTEBOOK**

# %% [markdown]
# ## Objectives
#
# * Fetch data from https://amtsblattportal.ch/api/v1/publications/xml, save as raw data and inspect data.
# * Find information about the API here:
#     https://amtsblattportal.ch/docs/api/#_api_reference
#     and here:
#     https://official-gazettes-portal.ch/#!/publish/info/technical-information
#
# ## Inputs
#
# * The data are from official gazettes portal.
# * The input data is a xml file that i can call with syntax: https://amtsblattportal.ch/api/v1/publications/csv?publicationStates=PUBLISHED&title.fr=Nouvelles entrées
# * You need to install requirements.txt with the commande: pip install -r requirements.txt
#
# ## Outputs
#
# * The output data is a csv file called inputs/metadata/gazette_metadata_jupyter.csv
#
# ## Additional Comments
#
# * The data is filtered, we keep only the subRubric{'HR01': 'New entries', 'HR02': 'Change', 'HR03': 'Deletion'} for our CRM

# %% [markdown]
# ---

# %% [markdown]
# # Install python packages in the notebooks

# %%
# %pip install requests xmltodict psycopg2-binary pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: xmltodict in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (0.14.2)
# Requirement already satisfied: psycopg2-binary in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.9.10)
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 78.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (2025.4.26)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 KB 88.1 MB/s eta 0:00:00
# Collecting numpy>=1.22.4
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 82.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.2.6 pandas-2.2.3 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * Storing the notebooks in a subfolder, therefore we change the working directory from its current folder to its parent folder

# %% [markdown]
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspace/GazetteAnaliticsTools/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspace/GazetteAnaliticsTools'

# %% [markdown]
# ---

# %% [markdown]
# # Fetch data from the Gazette API

# %% [markdown]
# ### Some imports:
# * os: for reading environment variables (e.g. your PG_DSN)
# * datetime: to compute today’s date
# * uuid: to generate UUIDs for new records
# * json: to serialize raw metadata into JSONB
# * requests: to call the Gazette API
# * xmltodict: to convert the XML response into Python dicts
# * psycopg2 / psycopg2.extras.execute_values: to connect and bulk-upsert into PostgreSQL

# %%
# 1. Imports Standard library
import os, datetime, uuid, json
# 2. Imports HTTP + XML parsing
import requests, xmltodict
# 3. Imports PostgreSQL driver
import psycopg2
from psycopg2.extras import execute_values
# 4. Imports Pandas for data analysis
import pandas as pd

# %% [markdown]
# ### Configurations

# %%
API_BASE   = "https://amtsblattportal.ch/api/v1/publications/xml"
PG_DSN     = os.getenv("PG_DSN", "postgresql://user:pass@localhost:5432/mydb")

# %% [markdown]
# ### Compute today's date

# %%
import datetime
manual = "15.01.2025"
today = datetime.datetime.strptime(manual, "%d.%m.%Y").date().isoformat()
# or
# today = datetime.date.today().isoformat()   # e.g. "2025-05-21"
print(today)
# Out:
# 2025-01-15

# %% [markdown]
# ### Fetch list of today's published gazettes

# %%
# We'll fetch all pages (if necessary) in one shot by setting size=2000
params = {
    "publicationStates":      "PUBLISHED",
    "publicationDate.start":  today,
    "publicationDate.end":    today,
    "tenant":                 "shab",        # only SHAB entries
    "pageRequest.size":       3000,          # up to 2000 per page
    "pageRequest.page":       0
}
resp = requests.get(API_BASE, params=params)
resp.raise_for_status()
bulk_xml = resp.text

# %% [markdown]
# ### Pars XML -> Python dict

# %%
data = xmltodict.parse(bulk_xml)

# 1. Locate the bulk-export root (namespace-prefix agnostic)
root_key = next((k for k in data if k.endswith("bulk-export")), None)
if root_key is None:
    raise KeyError("Could not find the bulk-export root element")

bulk = data[root_key]

# 2. Pull out the raw publication element(s)
pubs = bulk.get("publication", [])
if not isinstance(pubs, list):
    pubs = [pubs]

# 3. Extract all @schemaLocation attributes
schema_locations = [
    pub.get("@schemaLocation")
    for pub in pubs
    if "@schemaLocation" in pub
]
print(f"Retrieved {len(pubs)} SHAB publications today.")

# schema_locations
# Out:
# Retrieved 1530 SHAB publications today.

# %%
data2 = xmltodict.parse(bulk_xml)
# 1. Find the “bulk-export” root (namespace‐prefix agnostic)
root_key = next(
    (k for k in data2.keys() if k.endswith('bulk-export')), 
    None
)
if root_key is None:
    raise ValueError("Couldn't find the bulk-export root in response")

bulk = data2[root_key]

# 2. Extract the list of publications
items = bulk.get("publication", [])

# 3. Normalize to a list if it's a singleton
if not isinstance(items, list):
    items = [items]

items
# Out:
# [{'@ref': 'https://amtsblattportal.ch/api/v1/publications/4f614e43-c3e7-4df5-805f-4574ae3eabdc/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '4f614e43-c3e7-4df5-805f-4574ae3eabdc',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229436',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'JU',
#    'title': {'de': 'Löschung Société coopérative de la Guinguette en liquidation, Delémont',
#     'en': 'Deletion Société coopérative de la Guinguette en liquidation, Delémont',
#     'it': 'Cancellazione Société coopérative de la Guinguette en liquidation, Delémont',
#     'fr': 'Annulation Société coopérative de la Guinguette en liquidation, Delémont'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/e8608e46-d33e-4224-803f-d5d0cb6136bc/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'e8608e46-d33e-4224-803f-d5d0cb6136bc',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228931',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SG',
#    'title': {'de': 'Löschung DENTAMINA AG in Liquidation, Bad Ragaz',
#     'en': 'Deletion DENTAMINA AG in Liquidation, Bad Ragaz',
#     'it': 'Cancellazione DENTAMINA AG in Liquidation, Bad Ragaz',
#     'fr': 'Annulation DENTAMINA AG in Liquidation, Bad Ragaz'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/76a76b6a-7cc8-4378-b9f4-4c444315c931/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '76a76b6a-7cc8-4378-b9f4-4c444315c931',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228985',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'AG',
#    'title': {'de': 'Löschung schwarz logistics engineering, Reinach (AG)',
#     'en': 'Deletion schwarz logistics engineering, Reinach (AG)',
#     'it': 'Cancellazione schwarz logistics engineering, Reinach (AG)',
#     'fr': 'Annulation schwarz logistics engineering, Reinach (AG)'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/d8b04ace-8253-44e9-aae2-53434adbb228/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'd8b04ace-8253-44e9-aae2-53434adbb228',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228859',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SH',
#    'secondaryTenants': {'tenantCode': 'kabsh',
#     'publicationDate': '2025-01-15'},
#    'title': {'de': 'Löschung Wipf & Co. Immobilien, Lohn (SH)',
#     'en': 'Deletion Wipf & Co. Immobilien, Lohn (SH)',
#     'it': 'Cancellazione Wipf & Co. Immobilien, Lohn (SH)',
#     'fr': 'Annulation Wipf & Co. Immobilien, Lohn (SH)'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/4fe15a9e-237b-487a-9334-fd0fc248602e/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '4fe15a9e-237b-487a-9334-fd0fc248602e',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228978',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'AG',
#    'title': {'de': 'Löschung Freuler Haustechnik, Oberwil-Lieli',
#     'en': 'Deletion Freuler Haustechnik, Oberwil-Lieli',
#     'it': 'Cancellazione Freuler Haustechnik, Oberwil-Lieli',
#     'fr': 'Annulation Freuler Haustechnik, Oberwil-Lieli'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/c403d707-6d39-4e86-8796-9ac2a4827adc/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'c403d707-6d39-4e86-8796-9ac2a4827adc',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228930',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SG',
#    'title': {'de': 'Löschung Bourbon-Baron, Lübberstedt, Oberriet (SG)',
#     'en': 'Deletion Bourbon-Baron, Lübberstedt, Oberriet (SG)',
#     'it': 'Cancellazione Bourbon-Baron, Lübberstedt, Oberriet (SG)',
#     'fr': 'Annulation Bourbon-Baron, Lübberstedt, Oberriet (SG)'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/c865bf87-244a-4664-9385-cd480afead8b/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'c865bf87-244a-4664-9385-cd480afead8b',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229016',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'AG',
#    'title': {'de': 'Löschung LS Adventure KLG, Spreitenbach',
#     'en': 'Deletion LS Adventure KLG, Spreitenbach',
#     'it': 'Cancellazione LS Adventure KLG, Spreitenbach',
#     'fr': 'Annulation LS Adventure KLG, Spreitenbach'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/40ea91e8-6658-4c15-9933-5f614b360899/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '40ea91e8-6658-4c15-9933-5f614b360899',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228827',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'BS',
#    'title': {'de': 'Löschung Wallprint Momirovic, Basel',
#     'en': 'Deletion Wallprint Momirovic, Basel',
#     'it': 'Cancellazione Wallprint Momirovic, Basel',
#     'fr': 'Annulation Wallprint Momirovic, Basel'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/99314240-16ce-43d8-a758-ce620b10f3aa/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '99314240-16ce-43d8-a758-ce620b10f3aa',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228933',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SG',
#    'title': {'de': 'Löschung Max Kappler, Malerarbeiten, Zuzwil (SG)',
#     'en': 'Deletion Max Kappler, Malerarbeiten, Zuzwil (SG)',
#     'it': 'Cancellazione Max Kappler, Malerarbeiten, Zuzwil (SG)',
#     'fr': 'Annulation Max Kappler, Malerarbeiten, Zuzwil (SG)'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/ecb817fa-8a57-4cb4-abe0-b360f86df91a/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'ecb817fa-8a57-4cb4-abe0-b360f86df91a',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228932',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SG',
#    'title': {'de': 'Löschung Egli Trade, Lütisburg',
#     'en': 'Deletion Egli Trade, Lütisburg',
#     'it': 'Cancellazione Egli Trade, Lütisburg',
#     'fr': 'Annulation Egli Trade, Lütisburg'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/df4a8013-532f-4886-83d5-b50413d90ce5/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'df4a8013-532f-4886-83d5-b50413d90ce5',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'it',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229076',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'TI',
#    'secondaryTenants': {'tenantCode': 'kabti',
#     'publicationDate': '2025-01-15'},
#    'title': {'de': 'Löschung COMMUNICATION wl AT WORK SA in liquidazione, Lugano',
#     'en': 'Deletion COMMUNICATION wl AT WORK SA in liquidazione, Lugano',
#     'it': 'Cancellazione COMMUNICATION wl AT WORK SA in liquidazione, Lugano',
#     'fr': 'Annulation COMMUNICATION wl AT WORK SA in liquidazione, Lugano'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/ccc19443-b86c-4943-a867-a769bda2ac2a/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'ccc19443-b86c-4943-a867-a769bda2ac2a',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'it',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229083',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'TI',
#    'secondaryTenants': {'tenantCode': 'kabti',
#     'publicationDate': '2025-01-15'},
#    'title': {'de': 'Löschung IULIA INTERNATIONAL CONSULTING GmbH in liquidazione, Lugano',
#     'en': 'Deletion IULIA INTERNATIONAL CONSULTING GmbH in liquidazione, Lugano',
#     'it': 'Cancellazione IULIA INTERNATIONAL CONSULTING GmbH in liquidazione, Lugano',
#     'fr': 'Annulation IULIA INTERNATIONAL CONSULTING GmbH in liquidazione, Lugano'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/616bb07b-1df2-4d7c-b1e7-a005d6c4d866/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '616bb07b-1df2-4d7c-b1e7-a005d6c4d866',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'it',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229081',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'TI',
#    'secondaryTenants': {'tenantCode': 'kabti',
#     'publicationDate': '2025-01-15'},
#    'title': {'de': 'Löschung IMX Holding SA in liquidazione, Chiasso',
#     'en': 'Deletion IMX Holding SA in liquidazione, Chiasso',
#     'it': 'Cancellazione IMX Holding SA in liquidazione, Chiasso',
#     'fr': 'Annulation IMX Holding SA in liquidazione, Chiasso'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/360ade49-e9cd-448d-9231-d4adb186cfa4/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '360ade49-e9cd-448d-9231-d4adb186cfa4',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229091',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'VD',
#    'title': {'de': 'Löschung ARTI Ventilation-Serrurerie Sàrl en liquidation, Le Mont-sur-Lausanne',
#     'en': 'Deletion ARTI Ventilation-Serrurerie Sàrl en liquidation, Le Mont-sur-Lausanne',
#     'it': 'Cancellazione ARTI Ventilation-Serrurerie Sàrl en liquidation, Le Mont-sur-Lausanne',
#     'fr': 'Annulation ARTI Ventilation-Serrurerie Sàrl en liquidation, Le Mont-sur-Lausanne'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/cc2ff966-7959-4339-bdb5-54c72c50a185/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'cc2ff966-7959-4339-bdb5-54c72c50a185',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'it',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229086',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'TI',
#    'secondaryTenants': {'tenantCode': 'kabti',
#     'publicationDate': '2025-01-15'},
#    'title': {'de': 'Löschung Rillyfid SA in liquidazione, Lugano',
#     'en': 'Deletion Rillyfid SA in liquidazione, Lugano',
#     'it': 'Cancellazione Rillyfid SA in liquidazione, Lugano',
#     'fr': 'Annulation Rillyfid SA in liquidazione, Lugano'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/7e28c99d-51d5-4cf4-b8d8-f97706dccd5b/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '7e28c99d-51d5-4cf4-b8d8-f97706dccd5b',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'it',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229080',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'TI',
#    'secondaryTenants': {'tenantCode': 'kabti',
#     'publicationDate': '2025-01-15'},
#    'title': {'de': 'Löschung Graniti Ghisletta SA in liquidazione, Riviera',
#     'en': 'Deletion Graniti Ghisletta SA in liquidazione, Riviera',
#     'it': 'Cancellazione Graniti Ghisletta SA in liquidazione, Riviera',
#     'fr': 'Annulation Graniti Ghisletta SA in liquidazione, Riviera'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/3c459ae2-0769-48aa-be4e-4c7db3eb8177/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '3c459ae2-0769-48aa-be4e-4c7db3eb8177',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229102',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'VD',
#    'title': {'de': 'Löschung oprandi & partner romandie sa, Lausanne',
#     'en': 'Deletion oprandi & partner romandie sa, Lausanne',
#     'it': 'Cancellazione oprandi & partner romandie sa, Lausanne',
#     'fr': 'Annulation oprandi & partner romandie sa, Lausanne'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/ac35dd5a-8fb8-4116-a660-4fc1ee9dfcfc/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'ac35dd5a-8fb8-4116-a660-4fc1ee9dfcfc',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229105',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'VD',
#    'title': {'de': 'Löschung Restaurant de Hôtel de Ville Gomes Silva, Lucens',
#     'en': 'Deletion Restaurant de Hôtel de Ville Gomes Silva, Lucens',
#     'it': 'Cancellazione Restaurant de Hôtel de Ville Gomes Silva, Lucens',
#     'fr': 'Annulation Restaurant de Hôtel de Ville Gomes Silva, Lucens'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/69862ee0-fd35-46d3-b900-89641de3abf7/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '69862ee0-fd35-46d3-b900-89641de3abf7',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229098',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'VD',
#    'title': {'de': 'Löschung Mea-Pono SNC, Lausanne',
#     'en': 'Deletion Mea-Pono SNC, Lausanne',
#     'it': 'Cancellazione Mea-Pono SNC, Lausanne',
#     'fr': 'Annulation Mea-Pono SNC, Lausanne'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/16eed8f7-db53-4fb5-b528-823ba510d615/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '16eed8f7-db53-4fb5-b528-823ba510d615',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229226',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'VS',
#    'secondaryTenants': {'tenantCode': 'kabvs',
#     'publicationDate': '2025-01-15'},
#    'title': {'de': 'Löschung IF Investissements Financiers Sàrl, Collombey-Muraz',
#     'en': 'Deletion IF Investissements Financiers Sàrl, Collombey-Muraz',
#     'it': 'Cancellazione IF Investissements Financiers Sàrl, Collombey-Muraz',
#     'fr': 'Annulation IF Investissements Financiers Sàrl, Collombey-Muraz'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/014169b7-2898-4dea-b6fe-4811e81d43d7/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '014169b7-2898-4dea-b6fe-4811e81d43d7',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229435',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'JU',
#    'title': {'de': 'Löschung La Trappe SA en liquidation, Saignelégier',
#     'en': 'Deletion La Trappe SA en liquidation, Saignelégier',
#     'it': 'Cancellazione La Trappe SA en liquidation, Saignelégier',
#     'fr': 'Annulation La Trappe SA en liquidation, Saignelégier'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/3dd32609-edd5-4414-8330-9f70009c7b60/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '3dd32609-edd5-4414-8330-9f70009c7b60',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229432',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'JU',
#    'title': {'de': 'Löschung Aqua Pura sàrl en liquidation, Porrentruy',
#     'en': 'Deletion Aqua Pura sàrl en liquidation, Porrentruy',
#     'it': 'Cancellazione Aqua Pura sàrl en liquidation, Porrentruy',
#     'fr': 'Annulation Aqua Pura sàrl en liquidation, Porrentruy'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/4d40d36f-0e8e-4ec6-83de-5fe74de829df/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '4d40d36f-0e8e-4ec6-83de-5fe74de829df',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229329',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'GE',
#    'title': {'de': 'Löschung My Multiservices, Colares Barbosa, Meyrin',
#     'en': 'Deletion My Multiservices, Colares Barbosa, Meyrin',
#     'it': 'Cancellazione My Multiservices, Colares Barbosa, Meyrin',
#     'fr': 'Annulation My Multiservices, Colares Barbosa, Meyrin'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/515bed4c-1a7d-4652-b429-1f7c72702b3c/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '515bed4c-1a7d-4652-b429-1f7c72702b3c',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229207',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'VS',
#    'secondaryTenants': {'tenantCode': 'kabvs',
#     'publicationDate': '2025-01-15'},
#    'title': {'de': 'Löschung Bau-Atelier, Studer Franz, Visp',
#     'en': 'Deletion Bau-Atelier, Studer Franz, Visp',
#     'it': 'Cancellazione Bau-Atelier, Studer Franz, Visp',
#     'fr': 'Annulation Bau-Atelier, Studer Franz, Visp'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/6104c071-a723-4956-8085-62440fc547ca/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '6104c071-a723-4956-8085-62440fc547ca',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228826',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'BS',
#    'title': {'de': 'Löschung Ro-Mont Planung & Montagen GmbH in Liquidation, Basel',
#     'en': 'Deletion Ro-Mont Planung & Montagen GmbH in Liquidation, Basel',
#     'it': 'Cancellazione Ro-Mont Planung & Montagen GmbH in Liquidation, Basel',
#     'fr': 'Annulation Ro-Mont Planung & Montagen GmbH in Liquidation, Basel'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/998cf701-bc0b-4766-9c97-86c1ba424c64/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '998cf701-bc0b-4766-9c97-86c1ba424c64',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228777',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SO',
#    'title': {'de': 'Löschung Suhalj Pro Wear, Gerlafingen',
#     'en': 'Deletion Suhalj Pro Wear, Gerlafingen',
#     'it': 'Cancellazione Suhalj Pro Wear, Gerlafingen',
#     'fr': 'Annulation Suhalj Pro Wear, Gerlafingen'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/2a2ee4d3-cf8d-4d14-ad18-434c8c9174e3/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '2a2ee4d3-cf8d-4d14-ad18-434c8c9174e3',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229264',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'NE',
#    'title': {'de': 'Löschung Next Stop Restaurant, Ongu, Neuchâtel',
#     'en': 'Deletion Next Stop Restaurant, Ongu, Neuchâtel',
#     'it': 'Cancellazione Next Stop Restaurant, Ongu, Neuchâtel',
#     'fr': 'Annulation Next Stop Restaurant, Ongu, Neuchâtel'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/9164e9ea-5a83-45fc-9778-15bd2ed78ec0/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '9164e9ea-5a83-45fc-9778-15bd2ed78ec0',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229327',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'GE',
#    'title': {'de': 'Löschung HJB Rénovation Brahimi, Genève',
#     'en': 'Deletion HJB Rénovation Brahimi, Genève',
#     'it': 'Cancellazione HJB Rénovation Brahimi, Genève',
#     'fr': 'Annulation HJB Rénovation Brahimi, Genève'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/df9dd416-77b2-4cfa-8731-f34d0c9174aa/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'df9dd416-77b2-4cfa-8731-f34d0c9174aa',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229332',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'GE',
#    'title': {'de': 'Löschung Sole Mio, Ramon Rodriguez Madarnas, Genève',
#     'en': 'Deletion Sole Mio, Ramon Rodriguez Madarnas, Genève',
#     'it': 'Cancellazione Sole Mio, Ramon Rodriguez Madarnas, Genève',
#     'fr': 'Annulation Sole Mio, Ramon Rodriguez Madarnas, Genève'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/f2130f00-4864-4997-bc75-3023529f7dff/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'f2130f00-4864-4997-bc75-3023529f7dff',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006229324',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'GE',
#    'title': {'de': 'Löschung CARRARD (SILVER HOUSE BIJOUX), Genève',
#     'en': 'Deletion CARRARD (SILVER HOUSE BIJOUX), Genève',
#     'it': 'Cancellazione CARRARD (SILVER HOUSE BIJOUX), Genève',
#     'fr': 'Annulation CARRARD (SILVER HOUSE BIJOUX), Genève'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/375ae1d0-f4b3-43bc-87d0-14f74b238745/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '375ae1d0-f4b3-43bc-87d0-14f74b238745',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228774',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SO',
#    'title': {'de': 'Löschung PS-Arbeitssicherheit GmbH in Liquidation, Walterswil (SO)',
#     'en': 'Deletion PS-Arbeitssicherheit GmbH in Liquidation, Walterswil (SO)',
#     'it': 'Cancellazione PS-Arbeitssicherheit GmbH in Liquidation, Walterswil (SO)',
#     'fr': 'Annulation PS-Arbeitssicherheit GmbH in Liquidation, Walterswil (SO)'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/c130506f-fc9c-4ea9-9b64-1bab41c3ba79/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'c130506f-fc9c-4ea9-9b64-1bab41c3ba79',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228776',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SO',
#    'title': {'de': 'Löschung Simmler Transporte AG, Zweigniederlassung SimmlerCars, Balsthal',
#     'en': 'Deletion Simmler Transporte AG, Zweigniederlassung SimmlerCars, Balsthal',
#     'it': 'Cancellazione Simmler Transporte AG, Zweigniederlassung SimmlerCars, Balsthal',
#     'fr': 'Annulation Simmler Transporte AG, Zweigniederlassung SimmlerCars, Balsthal'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/bfb9938d-ce3e-40c6-a3c7-999f0dc8d807/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'bfb9938d-ce3e-40c6-a3c7-999f0dc8d807',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228766',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SO',
#    'title': {'de': 'Löschung Balaban - Food GmbH in Liquidation, Dulliken',
#     'en': 'Deletion Balaban - Food GmbH in Liquidation, Dulliken',
#     'it': 'Cancellazione Balaban - Food GmbH in Liquidation, Dulliken',
#     'fr': 'Annulation Balaban - Food GmbH in Liquidation, Dulliken'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/81f27517-bdc7-451d-90ba-1966cdbf56fa/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '81f27517-bdc7-451d-90ba-1966cdbf56fa',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228769',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SO',
#    'title': {'de': 'Löschung iMraff GmbH in Liquidation, Solothurn',
#     'en': 'Deletion iMraff GmbH in Liquidation, Solothurn',
#     'it': 'Cancellazione iMraff GmbH in Liquidation, Solothurn',
#     'fr': 'Annulation iMraff GmbH in Liquidation, Solothurn'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/ffcfcd27-a270-403b-b7b3-6758b5de5330/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'ffcfcd27-a270-403b-b7b3-6758b5de5330',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228771',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SO',
#    'title': {'de': 'Löschung Kimba AG in Liquidation, Hofstetten-Flüh',
#     'en': 'Deletion Kimba AG in Liquidation, Hofstetten-Flüh',
#     'it': 'Cancellazione Kimba AG in Liquidation, Hofstetten-Flüh',
#     'fr': 'Annulation Kimba AG in Liquidation, Hofstetten-Flüh'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/146abc95-fe18-4f40-9ddf-adcba059a86e/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': '146abc95-fe18-4f40-9ddf-adcba059a86e',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228773',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SO',
#    'title': {'de': 'Löschung Milch- und Landwirtschaftliche Genossenschaft Däniken und Umgebung in Liquidation, Däniken',
#     'en': 'Deletion Milch- und Landwirtschaftliche Genossenschaft Däniken und Umgebung in Liquidation, Däniken',
#     'it': 'Cancellazione Milch- und Landwirtschaftliche Genossenschaft Däniken und Umgebung in Liquidation, Däniken',
#     'fr': 'Annulation Milch- und Landwirtschaftliche Genossenschaft Däniken und Umgebung in Liquidation, Däniken'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/cb607239-dc9f-4431-a0bd-246c18bdf6f0/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR03-export.xsd',
#   'meta': {'id': 'cb607239-dc9f-4431-a0bd-246c18bdf6f0',
#    'rubric': 'HR',
#    'subRubric': 'HR03',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR03-1006228767',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'cantons': 'SO',
#    'title': {'de': 'Löschung Bistro Vin-De Çoban, Egerkingen',
#     'en': 'Deletion Bistro Vin-De Çoban, Egerkingen',
#     'it': 'Cancellazione Bistro Vin-De Çoban, Egerkingen',
#     'fr': 'Annulation Bistro Vin-De Çoban, Egerkingen'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/f2e62ee0-83f7-4938-a05f-c80a68239fed/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': 'f2e62ee0-83f7-4938-a05f-c80a68239fed',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006229400',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': "La mutation de l'entité juridique mentionnée a été effectuée dans le registre du commerce. <br />Publication selon les art. 9 et 35 ORC.",
#    'cantons': 'GE',
#    'title': {'de': 'Mutation Fabio FOSSATI - Architectes SA, Chêne-Bougeries',
#     'en': 'Change Fabio FOSSATI - Architectes SA, Chêne-Bougeries',
#     'it': 'Cambiamenti Fabio FOSSATI - Architectes SA, Chêne-Bougeries',
#     'fr': 'Mutation Fabio FOSSATI - Architectes SA, Chêne-Bougeries'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/7f0c6e5f-c6df-4393-9719-4f1bf38511d9/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': '7f0c6e5f-c6df-4393-9719-4f1bf38511d9',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006229415',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': "La mutation de l'entité juridique mentionnée a été effectuée dans le registre du commerce. <br />Publication selon les art. 9 et 35 ORC.",
#    'cantons': 'GE',
#    'title': {'de': 'Mutation Gunvor SA, Genève',
#     'en': 'Change Gunvor SA, Genève',
#     'it': 'Cambiamenti Gunvor SA, Genève',
#     'fr': 'Mutation Gunvor SA, Genève'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/047c1d8f-41ee-42aa-880f-cfa9ec569b22/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': '047c1d8f-41ee-42aa-880f-cfa9ec569b22',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006229412',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': "La mutation de l'entité juridique mentionnée a été effectuée dans le registre du commerce. <br />Publication selon les art. 9 et 35 ORC.",
#    'cantons': 'GE',
#    'title': {'de': 'Mutation GET Global Engineering Technology SA, Genève',
#     'en': 'Change GET Global Engineering Technology SA, Genève',
#     'it': 'Cambiamenti GET Global Engineering Technology SA, Genève',
#     'fr': 'Mutation GET Global Engineering Technology SA, Genève'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/7770c4bc-de91-4cce-b3fc-120d5f9d655a/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': '7770c4bc-de91-4cce-b3fc-120d5f9d655a',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006229414',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': "La mutation de l'entité juridique mentionnée a été effectuée dans le registre du commerce. <br />Publication selon les art. 9 et 35 ORC.",
#    'cantons': 'GE',
#    'title': {'de': 'Mutation Graphyte Labs SA, Genève',
#     'en': 'Change Graphyte Labs SA, Genève',
#     'it': 'Cambiamenti Graphyte Labs SA, Genève',
#     'fr': 'Mutation Graphyte Labs SA, Genève'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/2e2ebb27-9869-4ae9-bb55-465f72a97c60/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': '2e2ebb27-9869-4ae9-bb55-465f72a97c60',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006229418',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': "La mutation de l'entité juridique mentionnée a été effectuée dans le registre du commerce. <br />Publication selon les art. 9 et 35 ORC.",
#    'cantons': 'GE',
#    'title': {'de': 'Mutation HBK Investments Advisory SA, Genève',
#     'en': 'Change HBK Investments Advisory SA, Genève',
#     'it': 'Cambiamenti HBK Investments Advisory SA, Genève',
#     'fr': 'Mutation HBK Investments Advisory SA, Genève'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/ddceb583-2af6-4e96-aa27-a093311b0c3b/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': 'ddceb583-2af6-4e96-aa27-a093311b0c3b',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006229411',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': "La mutation de l'entité juridique mentionnée a été effectuée dans le registre du commerce. <br />Publication selon les art. 9 et 35 ORC.",
#    'cantons': 'GE',
#    'title': {'de': "Mutation Gentlemen's Factory Sàrl, Genève",
#     'en': "Change Gentlemen's Factory Sàrl, Genève",
#     'it': "Cambiamenti Gentlemen's Factory Sàrl, Genève",
#     'fr': "Mutation Gentlemen's Factory Sàrl, Genève"}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/b4d1900c-2dc9-4c0a-93a6-cb4acf1fc762/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': 'b4d1900c-2dc9-4c0a-93a6-cb4acf1fc762',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006229406',
#    'publicationState': 'PUBLISHED',
# ...
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006228759',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': 'Die Mutation der aufgeführten Rechtseinheit wurde im Handelsregister vorgenommen. <br />Publikation nach HRegV Art. 9 und Art. 35.',
#    'cantons': 'SO',
#    'title': {'de': 'Mutation Schreinerei Marco Steiner GmbH, Solothurn, neu Schreinerei Marco Steiner GmbH in Liquidation',
#     'en': 'Change Schreinerei Marco Steiner GmbH, Solothurn, new Schreinerei Marco Steiner GmbH in Liquidation',
#     'it': 'Cambiamenti Schreinerei Marco Steiner GmbH, Solothurn, nuovo Schreinerei Marco Steiner GmbH in Liquidation',
#     'fr': 'Mutation Schreinerei Marco Steiner GmbH, Solothurn, nouveau Schreinerei Marco Steiner GmbH in Liquidation'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/ac6b9219-df23-43c2-94bb-b83a7d9702cb/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': 'ac6b9219-df23-43c2-94bb-b83a7d9702cb',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006228863',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': 'Die Mutation der aufgeführten Rechtseinheit wurde im Handelsregister vorgenommen. <br />Publikation nach HRegV Art. 9 und Art. 35.',
#    'cantons': 'AR',
#    'secondaryTenants': {'tenantCode': 'kabar',
#     'publicationDate': '2025-01-15'},
#    'title': {'de': 'Mutation Nata AG, Walzenhausen',
#     'en': 'Change Nata AG, Walzenhausen',
#     'it': 'Cambiamenti Nata AG, Walzenhausen',
#     'fr': 'Mutation Nata AG, Walzenhausen'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/c8046861-be79-4761-b363-7876158ec5af/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': 'c8046861-be79-4761-b363-7876158ec5af',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006228892',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': 'Die Mutation der aufgeführten Rechtseinheit wurde im Handelsregister vorgenommen. <br />Publikation nach HRegV Art. 9 und Art. 35.',
#    'cantons': 'SG',
#    'title': {'de': 'Mutation Contrag Holding AG, Gossau (SG)',
#     'en': 'Change Contrag Holding AG, Gossau (SG)',
#     'it': 'Cambiamenti Contrag Holding AG, Gossau (SG)',
#     'fr': 'Mutation Contrag Holding AG, Gossau (SG)'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/e4a8a873-7af0-48f6-8c08-c3f71aef1909/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': 'e4a8a873-7af0-48f6-8c08-c3f71aef1909',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006228887',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': 'Die Mutation der aufgeführten Rechtseinheit wurde im Handelsregister vorgenommen. <br />Publikation nach HRegV Art. 9 und Art. 35.',
#    'cantons': 'SG',
#    'title': {'de': 'Mutation Baumschlager Eberle St.Gallen AG, St. Gallen',
#     'en': 'Change Baumschlager Eberle St.Gallen AG, St. Gallen',
#     'it': 'Cambiamenti Baumschlager Eberle St.Gallen AG, St. Gallen',
#     'fr': 'Mutation Baumschlager Eberle St.Gallen AG, St. Gallen'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/7620ae71-9412-4a08-856d-b5d7be19ba87/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': '7620ae71-9412-4a08-856d-b5d7be19ba87',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006228898',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': 'Die Mutation der aufgeführten Rechtseinheit wurde im Handelsregister vorgenommen. <br />Publikation nach HRegV Art. 9 und Art. 35.',
#    'cantons': 'SG',
#    'title': {'de': 'Mutation Dupper Sanitär und Heizung GmbH, Steinach',
#     'en': 'Change Dupper Sanitär und Heizung GmbH, Steinach',
#     'it': 'Cambiamenti Dupper Sanitär und Heizung GmbH, Steinach',
#     'fr': 'Mutation Dupper Sanitär und Heizung GmbH, Steinach'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/6b272902-2679-4fc6-b8f3-d26b950c5ce0/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': '6b272902-2679-4fc6-b8f3-d26b950c5ce0',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006228883',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': 'Die Mutation der aufgeführten Rechtseinheit wurde im Handelsregister vorgenommen. <br />Publikation nach HRegV Art. 9 und Art. 35.',
#    'cantons': 'SG',
#    'title': {'de': 'Mutation "Buttinette" Textil-Versandhaus GmbH, Wertingen (DE), Zweigniederlassung Diepoldsau, Diepoldsau',
#     'en': 'Change "Buttinette" Textil-Versandhaus GmbH, Wertingen (DE), Zweigniederlassung Diepoldsau, Diepoldsau',
#     'it': 'Cambiamenti "Buttinette" Textil-Versandhaus GmbH, Wertingen (DE), Zweigniederlassung Diepoldsau, Diepoldsau',
#     'fr': 'Mutation "Buttinette" Textil-Versandhaus GmbH, Wertingen (DE), Zweigniederlassung Diepoldsau, Diepoldsau'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/ad2e8914-0663-4127-a81e-b7eb8662be5c/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': 'ad2e8914-0663-4127-a81e-b7eb8662be5c',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006228864',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': 'Die Mutation der aufgeführten Rechtseinheit wurde im Handelsregister vorgenommen. <br />Publikation nach HRegV Art. 9 und Art. 35.',
#    'cantons': 'AR',
#    'secondaryTenants': {'tenantCode': 'kabar',
#     'publicationDate': '2025-01-15'},
#    'title': {'de': 'Mutation Perla Pannonia Inhaber Tibor Balla, Herisau, neu Urnäsch',
#     'en': 'Change Perla Pannonia Inhaber Tibor Balla, Herisau, new Urnäsch',
#     'it': 'Cambiamenti Perla Pannonia Inhaber Tibor Balla, Herisau, nuovo Urnäsch',
#     'fr': 'Mutation Perla Pannonia Inhaber Tibor Balla, Herisau, nouveau Urnäsch'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/a1b86c10-7879-4d44-b08c-32a78a3356de/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': 'a1b86c10-7879-4d44-b08c-32a78a3356de',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006228384',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': 'Die Mutation der aufgeführten Rechtseinheit wurde im Handelsregister vorgenommen. <br />Publikation nach HRegV Art. 9 und Art. 35.',
#    'cantons': 'ZH',
#    'title': {'de': 'Mutation Life JackIT GmbH, Regensdorf, neu Aesch (BL)',
#     'en': 'Change Life JackIT GmbH, Regensdorf, new Aesch (BL)',
#     'it': 'Cambiamenti Life JackIT GmbH, Regensdorf, nuovo Aesch (BL)',
#     'fr': 'Mutation Life JackIT GmbH, Regensdorf, nouveau Aesch (BL)'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/b5acca28-f97e-4709-b294-7caa514ec795/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR02-export.xsd',
#   'meta': {'id': 'b5acca28-f97e-4709-b294-7caa514ec795',
#    'rubric': 'HR',
#    'subRubric': 'HR02',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR02-1006228357',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': 'Die Mutation der aufgeführten Rechtseinheit wurde im Handelsregister vorgenommen. <br />Publikation nach HRegV Art. 9 und Art. 35.',
#    'cantons': 'ZH',
#    'title': {'de': 'Mutation UBV Lanz AG, Zollikon',
#     'en': 'Change UBV Lanz AG, Zollikon',
#     'it': 'Cambiamenti UBV Lanz AG, Zollikon',
#     'fr': 'Mutation UBV Lanz AG, Zollikon'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/6a5b7041-0f3a-4512-9301-aedc9f6867bd/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR01-export.xsd',
#   'meta': {'id': '6a5b7041-0f3a-4512-9301-aedc9f6867bd',
#    'rubric': 'HR',
#    'subRubric': 'HR01',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR01-1006228780',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': 'Die aufgeführte Rechtseinheit wurde ins Handelsregister aufgenommen und ist rechtsfähig. <br />Publikation nach HRegV Art. 9 und Art. 35.',
#    'cantons': 'BS',
#    'title': {'de': 'Neueintragung NLS HOLDING Anonim Sirketi, Cankaya/Ankara (TR), Zweigniederlassung Basel, Basel',
#     'en': 'New entries NLS HOLDING Anonim Sirketi, Cankaya/Ankara (TR), Zweigniederlassung Basel, Basel',
#     'it': 'Nuove registrazioni NLS HOLDING Anonim Sirketi, Cankaya/Ankara (TR), Zweigniederlassung Basel, Basel',
#     'fr': 'Nouvelles entrées NLS HOLDING Anonim Sirketi, Cankaya/Ankara (TR), Zweigniederlassung Basel, Basel'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/19f84475-16b1-403a-b015-41720bdef146/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR01-export.xsd',
#   'meta': {'id': '19f84475-16b1-403a-b015-41720bdef146',
#    'rubric': 'HR',
#    'subRubric': 'HR01',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR01-1006228736',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': "L'entité juridique mentionnée a été inscrite au registre du commerce et jouit de la capacité juridique. <br />Publication selon les art. 9 et 35 ORC.",
#    'cantons': 'FR',
#    'title': {'de': 'Neueintragung Kiosque la civette Sàrl, Fribourg',
#     'en': 'New entries Kiosque la civette Sàrl, Fribourg',
#     'it': 'Nuove registrazioni Kiosque la civette Sàrl, Fribourg',
#     'fr': 'Nouvelles entrées Kiosque la civette Sàrl, Fribourg'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/6933b11f-c503-4dd3-9fe3-37b680266a6c/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR01-export.xsd',
#   'meta': {'id': '6933b11f-c503-4dd3-9fe3-37b680266a6c',
#    'rubric': 'HR',
#    'subRubric': 'HR01',
#    'language': 'fr',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR01-1006228670',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': "L'entité juridique mentionnée a été inscrite au registre du commerce et jouit de la capacité juridique. <br />Publication selon les art. 9 et 35 ORC.",
#    'cantons': 'FR',
#    'title': {'de': 'Neueintragung Quentin CHAGNARD Pose Fenêtres et Agencement, Châtel-Saint-Denis',
#     'en': 'New entries Quentin CHAGNARD Pose Fenêtres et Agencement, Châtel-Saint-Denis',
#     'it': 'Nuove registrazioni Quentin CHAGNARD Pose Fenêtres et Agencement, Châtel-Saint-Denis',
#     'fr': 'Nouvelles entrées Quentin CHAGNARD Pose Fenêtres et Agencement, Châtel-Saint-Denis'}}},
#  {'@ref': 'https://amtsblattportal.ch/api/v1/publications/b0eb09c5-6588-40a6-81bd-712bbe5f458e/xml',
#   '@schemaLocation': 'https://amtsblattportal.ch/api/v1/schemas/shab/1.23/HR01-export.xsd',
#   'meta': {'id': 'b0eb09c5-6588-40a6-81bd-712bbe5f458e',
#    'rubric': 'HR',
#    'subRubric': 'HR01',
#    'language': 'de',
#    'registrationOffice': {'id': 'e15a629a-a08d-11e8-aa11-0050569d3c43',
#     'displayName': 'Bundesamt für Justiz (BJ), Eidgenössisches Amt für das Handelsregister',
#     'street': 'Bundesrain',
#     'streetNumber': '20',
#     'swissZipCode': '3003',
#     'town': 'Bern',
#     'containsPostOfficeBox': 'false'},
#    'publicationNumber': 'HR01-1006228740',
#    'publicationState': 'PUBLISHED',
#    'publicationDate': '2025-01-15',
#    'primaryTenantCode': 'shab',
#    'legalRemedy': 'Die aufgeführte Rechtseinheit wurde ins Handelsregister aufgenommen und ist rechtsfähig. <br />Publikation nach HRegV Art. 9 und Art. 35.',
#    'cantons': 'SO',
#    'title': {'de': 'Neueintragung Gari, Inh. Tamang, Luterbach',
#     'en': 'New entries Gari, Inh. Tamang, Luterbach',
#     'it': 'Nuove registrazioni Gari, Inh. Tamang, Luterbach',
#     'fr': 'Nouvelles entrées Gari, Inh. Tamang, Luterbach'}}},
#  ...]

# %% [markdown]
# ### Transform into flat rows

# %%
#1. Where to write
os.makedirs("inputs/metadata", exist_ok=True)
output_path = "inputs/metadata/gazette_metadata_jupyter.csv"

# %%
#2. Define the mapping
rubric_map = {
    "HR01": "New entries",
    "HR02": "Change",
    "HR03": "Deletion"
}

#3. Build the rows with an extra "entryType" column
rows = []
for pub in items:
    meta = pub.get("meta", {})
    sub = meta.get("subRubric")

    #4. Filter to HR01, HR02, HR03
    if sub not in rubric_map:
        continue

    #5. Build the row
    row = {
        "ref":            pub.get("@ref"),
        "schemaLocation": pub.get("@schemaLocation"),
        "id":             meta.get("id"),
        "subRubric":      sub,
        "publicationDate":    meta.get("publicationDate"),
        "legalRemedy":    meta.get("legalRemedy"),
        "title_en":       meta.get("title", {}).get("en"),
        #6. Map the data
        "entryType":      rubric_map[sub]
    }

    rows.append(row)

# %%
#7. Dump to CSV (delete and recreate if exists, otherwise write header)
df = pd.DataFrame(rows)

if os.path.exists(output_path):
    os.remove(output_path)

# 2. Write afresh, including the header
df.to_csv(output_path, index=False)

print(f"Wrote {len(df)} rows to {output_path}")
# Out:
# Wrote 1273 rows to inputs/metadata/gazette_metadata_jupyter.csv

# %% [markdown]
# ---

# %% [markdown]
# # Inspect meta data

# %% [markdown]
# Section 2 content

# %%
df = pd.read_csv(f"inputs/metadata/gazette_metadata_jupyter.csv")
df.head()
# Out:
#                                                  ref  \
# 0  https://amtsblattportal.ch/api/v1/publications...
# 1  https://amtsblattportal.ch/api/v1/publications...
# 2  https://amtsblattportal.ch/api/v1/publications...
# 3  https://amtsblattportal.ch/api/v1/publications...
# 4  https://amtsblattportal.ch/api/v1/publications...
#
#                                       schemaLocation  \
# 0  https://amtsblattportal.ch/api/v1/schemas/shab...
# 1  https://amtsblattportal.ch/api/v1/schemas/shab...
# 2  https://amtsblattportal.ch/api/v1/schemas/shab...
# 3  https://amtsblattportal.ch/api/v1/schemas/shab...
# 4  https://amtsblattportal.ch/api/v1/schemas/shab...
#
#                                      id subRubric publicationDate legalRemedy  \
# 0  4f614e43-c3e7-4df5-805f-4574ae3eabdc      HR03      2025-01-15         NaN
# 1  e8608e46-d33e-4224-803f-d5d0cb6136bc      HR03      2025-01-15         NaN
# 2  76a76b6a-7cc8-4378-b9f4-4c444315c931      HR03      2025-01-15         NaN
# 3  d8b04ace-8253-44e9-aae2-53434adbb228      HR03      2025-01-15         NaN
# 4  4fe15a9e-237b-487a-9334-fd0fc248602e      HR03      2025-01-15         NaN
#
#                                             title_en entryType
# 0  Deletion Société coopérative de la Guinguette ...  Deletion
# 1    Deletion DENTAMINA AG in Liquidation, Bad Ragaz  Deletion
# 2  Deletion schwarz logistics engineering, Reinac...  Deletion
# 3          Deletion Wipf & Co. Immobilien, Lohn (SH)  Deletion
# 4        Deletion Freuler Haustechnik, Oberwil-Lieli  Deletion

# %% [markdown]
# DataFrame Summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ref              1273 non-null   object
#  1   schemaLocation   1273 non-null   object
#  2   id               1273 non-null   object
#  3   subRubric        1273 non-null   object
#  4   publicationDate  1273 non-null   object
#  5   legalRemedy      1148 non-null   object
#  6   title_en         1273 non-null   object
#  7   entryType        1273 non-null   object
# dtypes: object(8)
# memory usage: 79.7+ KB

# %% [markdown]
# We want to check if there are duplicated `id`: There are not.

# %%
df[df.duplicated(subset=['id'])]
# Out:
# Empty DataFrame
# Columns: [ref, schemaLocation, id, subRubric, publicationDate, legalRemedy, title_en, entryType]
# Index: []

# %% [markdown]
# Find missing values

# %%
df.isna().sum()
# Out:
# ref                  0
# schemaLocation       0
# id                   0
# subRubric            0
# publicationDate      0
# legalRemedy        125
# title_en             0
# entryType            0
# dtype: int64

# %% [markdown]
# Evaluating distribution and shape of a variable with missing data

# %%
#1. Variable containing missing data
missing_data = df.columns[df.isna().sum() > 0].to_list()
missing_data

#2. Exemple of missing data (not missing) in order to understand what to do with missing values
# for col in missing_data:
#     unique_values = df[col].dropna().unique()[:5]
#     print(f"{col}: {unique_values}\n")

#3. Trying to understand the importance of the missing data, Filter rows where 'xxx' is missing and display the first 5
# missing_rows = df[df['legalRemedy'].isna()]
# print(missing_rows.head(5))

#4. Print a list of unique missing variable, Filter rows where 'xxx' is missing and get unique 'yyy' values
unique_yyy = df[df['legalRemedy'].isna()]['subRubric'].unique()
print(unique_yyy)
# Out:
# ['HR03']

# %% [markdown]
# Print unique liste of subRubric in order to make sure that we got all necessary sementic.

# %%
# 1. Make sure there are no missing values
subrubrics = df['subRubric'].dropna()

# 2. Extract unique values as a list
unique_subrubrics = subrubrics.unique().tolist()
print(f"Total {len(unique_subrubrics)} subrubrics")

# 3. Print them
for sr, cnt in df['subRubric'].value_counts().items():
    print(f"{sr}: {cnt}")
# Out:
# Total 3 subrubrics
# HR02: 928
# HR01: 220
# HR03: 125

# %% [markdown]
# Other way of knowing the meaning of all the subrubrics

# %%
# 1. Group by subRubric, aggregating count and the first title_en we see
summary = (
    df
    .groupby("subRubric")["title_en"]
    .agg(count="size", example_title_en="first")
    .reset_index()
)

# 2. Print it out
for _, row in summary.iterrows():
    print(f"{row['subRubric']}: {row['count']} — example title: {row['example_title_en']}")
# Out:
# HR01: 220 — example title: New entries Fire Technic SA, Genève
# HR02: 928 — example title: Change Fabio FOSSATI - Architectes SA, Chêne-Bougeries
# HR03: 125 — example title: Deletion Société coopérative de la Guinguette en liquidation, Delémont

# %% [markdown]
# ---

# %% [markdown]
# # Conclusion and next step

# %% [markdown]
# In conclusion we saw that the daily data is not very large.
#
# We filtered and kept only subRubric{'HR01': 'New entries', 'HR02': 'Change', 'HR03': 'Deletion'}.
#
# Next step is to call each "ref"/"@ref" and fetch further informations.
